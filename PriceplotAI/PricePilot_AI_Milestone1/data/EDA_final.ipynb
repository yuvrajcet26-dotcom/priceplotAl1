# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e8f14fbc-64f2-44bf-9240-355683f7929d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8f14fbc-64f2-44bf-9240-355683f7929d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ==========================
# EDA - Brazilian E-commerce Olist Dataset
# ==========================

# 1. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Load Dataset
df = pd.read_csv("/content/brazilian_ecommerce_olist.csv")

# 3. Basic Information
print("First 5 Rows")
print(df.head())

print("\nLast 5 Rows")
print(df.tail())

print("\nShape of Dataset")
print(df.shape)

print("\nColumn Names")
print(df.columns)

print("\nDataset Information")
print(df.info())

print("\nData Types")
print(df.dtypes)

# 4. Missing Values
print("\nMissing Values")
print(df.isnull().sum())

# 5. Duplicate Values
print("\nDuplicate Rows")
print(df.duplicated().sum())

# Remove duplicates if needed
df.drop_duplicates(inplace=True)

# 6. Statistical Summary
print("\nStatistical Summary")
print(df.describe())

print("\nStatistical Summary (Including Categorical)")
print(df.describe(include='all'))

# 7. Unique Values
print("\nUnique Values in Each Column")
print(df.nunique())

# 8. Correlation Matrix
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(8,5))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# 9. Distribution of Numerical Columns
numeric_df.hist(figsize=(10,6), bins=20)
plt.tight_layout()
plt.show()

# 10. Boxplots for Numerical Columns
for col in numeric_df.columns:
    plt.figure(figsize=(5,3))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# 11. Countplots for Categorical Columns
categorical_cols = df.select_dtypes(include="object").columns

for col in categorical_cols:
    plt.figure(figsize=(8,4))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f"Countplot of {col}")
    plt.tight_layout()
    plt.show()

# 12. Review Score Distribution
plt.figure(figsize=(6,4))
sns.countplot(x=df["review_score"])
plt.title("Review Score Distribution")
plt.show()

# 13. Payment Type Distribution
plt.figure(figsize=(6,4))
sns.countplot(x=df["payment_type"])
plt.title("Payment Type Distribution")
plt.xticks(rotation=45)
plt.show()

# 14. Customer State Distribution (Top 10)
plt.figure(figsize=(8,5))
top_states = df["customer_state"].value_counts().head(10)
sns.barplot(x=top_states.index, y=top_states.values)
plt.title("Top 10 Customer States")
plt.xlabel("State")
plt.ylabel("Count")
plt.show()

# 15. Sales Channel Distribution
plt.figure(figsize=(6,4))
sns.countplot(x=df["sales_channel"])
plt.title("Sales Channel Distribution")
plt.xticks(rotation=45)
plt.show()

# 16. Price Distribution
plt.figure(figsize=(7,4))
sns.histplot(df["price"], bins=30, kde=True)
plt.title("Price Distribution")
plt.show()

# 17. Freight Value Distribution
plt.figure(figsize=(7,4))
sns.histplot(df["freight_value"], bins=30, kde=True)
plt.title("Freight Value Distribution")
plt.show()

# 18. Scatter Plot (Price vs Freight Value)
plt.figure(figsize=(6,4))
sns.scatterplot(x="price", y="freight_value", data=df)
plt.title("Price vs Freight Value")
plt.show()

# 19. Pairplot of Numerical Features
sns.pairplot(numeric_df)
plt.show()

# 20. Convert Timestamp and Extract Date Features
df["order_purchase_timestamp"] = pd.to_datetime(df["order_purchase_timestamp"])

df["Year"] = df["order_purchase_timestamp"].dt.year
df["Month"] = df["order_purchase_timestamp"].dt.month
df["Day"] = df["order_purchase_timestamp"].dt.day
df["Hour"] = df["order_purchase_timestamp"].dt.hour

# Monthly Orders
plt.figure(figsize=(8,4))
sns.countplot(x="Month", data=df)
plt.title("Monthly Orders")
plt.show()

# Hourly Orders
plt.figure(figsize=(8,4))
sns.countplot(x="Hour", data=df)
plt.title("Orders by Hour")
plt.show()

print("\nEDA Completed Successfully!")
# Out:
# First 5 Rows
#          order_id     product_id order_purchase_timestamp   price  \
# 0  ORD-2025-10002  PROD_SPRT_002      2025-01-01 18:05:00  249.28
# 1  ORD-2025-10003   PROD_APP_003      2025-01-01 11:24:00   53.91
# 2  ORD-2025-10004  PROD_HOME_001      2025-01-01 13:44:00   83.86
# 3  ORD-2025-10005   PROD_APP_001      2025-01-01 20:47:00   59.47
# 4  ORD-2025-10006  PROD_SPRT_001      2025-01-01 17:47:00   34.73
#
#    freight_value customer_state    payment_type        sales_channel  \
# 0           5.66             WA  digital_wallet           Mobile App
# 1          14.79             NY     credit_card   Amazon Marketplace
# 2           5.96             IL  digital_wallet  Direct Online Store
# 3           6.81             NC       gift_card   Amazon Marketplace
# 4           6.43             IL     credit_card           Mobile App
#
#    review_score
# 0             5
# 1             5
# 2             3
# 3             5
# 4             4
#
# Last 5 Rows
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distplot for Price
plt.figure(figsize=(6,4))
sns.distplot(df["price"], bins=30, kde=True)
plt.title("Distribution Plot of Price")
plt.show()

# Distplot for Freight Value
plt.figure(figsize=(6,4))
sns.distplot(df["freight_value"], bins=30, kde=True)
plt.title("Distribution Plot of Freight Value")
plt.show()

# Distplot for Review Score
plt.figure(figsize=(6,4))
sns.distplot(df["review_score"], bins=5, kde=True)
plt.title("Distribution Plot of Review Score")
plt.show()
# Out:
# /tmp/ipykernel_1876/1277950186.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"], bins=30, kde=True)
# /tmp/ipykernel_1876/1277950186.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["freight_value"], bins=30, kde=True)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2fbcb115-3c01-4637-96a4-ace10fffa3d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2fbcb115-3c01-4637-96a4-ace10fffa3d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ============================================================
# EDA - Amazon Product Pricing Dataset
# ============================================================

# 1. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set_theme(style="whitegrid")

# ============================================================
# 2. Load Dataset
# ============================================================

import pandas as pd

filename = next(iter(uploaded))
df = pd.read_csv(filename)

print("Dataset loaded successfully!")
print("Shape:", df.shape)
display(df.head())
# ============================================================
# 3. Basic Information
# ============================================================

print("=" * 60)
print("FIRST 5 ROWS")
print("=" * 60)
print(df.head())

print("\n" + "=" * 60)
print("LAST 5 ROWS")
print("=" * 60)
print(df.tail())

print("\n" + "=" * 60)
print("SHAPE OF DATASET")
print("=" * 60)
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\n" + "=" * 60)
print("COLUMN NAMES")
print("=" * 60)
print(df.columns.tolist())

print("\n" + "=" * 60)
print("DATASET INFORMATION")
print("=" * 60)
df.info()

print("\n" + "=" * 60)
print("DATA TYPES")
print("=" * 60)
print(df.dtypes)

# ============================================================
# 4. Missing Values
# ============================================================

print("\n" + "=" * 60)
print("MISSING VALUES")
print("=" * 60)

missing_values = df.isnull().sum()
print(missing_values)

print("\nTotal Missing Values:", df.isnull().sum().sum())

# Missing-value percentage
missing_percentage = (df.isnull().sum() / len(df)) * 100
print("\nMissing Value Percentage:")
print(missing_percentage)

# ============================================================
# 5. Duplicate Values
# ============================================================

print("\n" + "=" * 60)
print("DUPLICATE ROWS")
print("=" * 60)

duplicates = df.duplicated().sum()
print("Number of duplicate rows:", duplicates)

# Remove duplicates
if duplicates > 0:
    df.drop_duplicates(inplace=True)
    print("Duplicates removed.")

# ============================================================
# 6. Statistical Summary
# ============================================================

print("\n" + "=" * 60)
print("STATISTICAL SUMMARY")
print("=" * 60)

print(df.describe())

print("\n" + "=" * 60)
print("STATISTICAL SUMMARY INCLUDING CATEGORICAL DATA")
print("=" * 60)

print(df.describe(include="all"))

# ============================================================
# 7. Unique Values
# ============================================================

print("\n" + "=" * 60)
print("UNIQUE VALUES")
print("=" * 60)

print(df.nunique())

# ============================================================
# 8. Numerical and Categorical Columns
# ============================================================

numeric_df = df.select_dtypes(include=np.number)
categorical_cols = df.select_dtypes(include="object").columns

print("\nNumerical Columns:")
print(numeric_df.columns.tolist())

print("\nCategorical Columns:")
print(categorical_cols.tolist())

# ============================================================
# 9. Correlation Matrix
# ============================================================

plt.figure(figsize=(10, 7))

correlation = numeric_df.corr()

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Matrix - Amazon Product Pricing")
plt.tight_layout()
plt.show()

# ============================================================
# 10. Distribution of Numerical Variables
# ============================================================

numeric_df.hist(
    figsize=(14, 10),
    bins=15,
    edgecolor="black"
)

plt.suptitle(
    "Distribution of Numerical Variables",
    fontsize=16
)

plt.tight_layout()
plt.show()

# ============================================================
# 11. Boxplots for Numerical Columns
# ============================================================

for col in numeric_df.columns:

    plt.figure(figsize=(7, 4))

    sns.boxplot(x=df[col])

    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)

    plt.tight_layout()
    plt.show()

# ============================================================
# 12. Categorical Variable Analysis
# ============================================================

for col in categorical_cols:

    plt.figure(figsize=(8, 5))

    order = df[col].value_counts().index

    sns.countplot(
        y=df[col],
        order=order
    )

    plt.title(f"Distribution of {col}")
    plt.xlabel("Count")
    plt.ylabel(col)

    plt.tight_layout()
    plt.show()

# ============================================================
# 13. Category Distribution
# ============================================================

plt.figure(figsize=(7, 5))

category_counts = df["category"].value_counts()

sns.barplot(
    x=category_counts.index,
    y=category_counts.values
)

plt.title("Product Category Distribution")
plt.xlabel("Category")
plt.ylabel("Number of Products")

plt.xticks(rotation=30)

plt.tight_layout()
plt.show()

# ============================================================
# 14. Sub-Category Distribution
# ============================================================

plt.figure(figsize=(9, 5))

subcategory_counts = df["sub_category"].value_counts()

sns.barplot(
    x=subcategory_counts.index,
    y=subcategory_counts.values
)

plt.title("Product Sub-Category Distribution")
plt.xlabel("Sub-Category")
plt.ylabel("Number of Products")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# ============================================================
# 15. Actual Price vs Discounted Price
# ============================================================

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="actual_price_msrp",
    y="discounted_price",
    s=100
)

plt.title("Actual Price vs Discounted Price")
plt.xlabel("Actual Price / MSRP")
plt.ylabel("Discounted Price")

plt.tight_layout()
plt.show()

# ============================================================
# 16. Cost Price vs Discounted Price
# ============================================================

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="cost_price",
    y="discounted_price",
    s=100
)

plt.title("Cost Price vs Discounted Price")
plt.xlabel("Cost Price")
plt.ylabel("Discounted Price")

plt.tight_layout()
plt.show()

# ============================================================
# 17. Price Distribution
# ============================================================

plt.figure(figsize=(8, 5))

sns.histplot(
    df["actual_price_msrp"],
    bins=15,
    kde=True
)

plt.title("Distribution of Actual Price / MSRP")
plt.xlabel("Actual Price")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# ============================================================
# 18. Discounted Price Distribution
# ============================================================

plt.figure(figsize=(8, 5))

sns.histplot(
    df["discounted_price"],
    bins=15,
    kde=True
)

plt.title("Distribution of Discounted Price")
plt.xlabel("Discounted Price")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# ============================================================
# 19. Discount Percentage Distribution
# ============================================================

plt.figure(figsize=(8, 5))

sns.histplot(
    df["discount_percentage"],
    bins=10,
    kde=True
)

plt.title("Distribution of Discount Percentage")
plt.xlabel("Discount Percentage")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# ============================================================
# 20. Rating Distribution
# ============================================================

plt.figure(figsize=(7, 5))

sns.histplot(
    df["rating"],
    bins=10,
    kde=True
)

plt.title("Product Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# ============================================================
# 21. Rating Count Distribution
# ============================================================

plt.figure(figsize=(8, 5))

sns.histplot(
    df["rating_count"],
    bins=15,
    kde=True
)

plt.title("Distribution of Rating Count")
plt.xlabel("Rating Count")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# ============================================================
# 22. Stock Availability
# ============================================================

plt.figure(figsize=(8, 5))

sns.histplot(
    df["stock_available"],
    bins=15,
    kde=True
)

plt.title("Distribution of Stock Availability")
plt.xlabel("Stock Available")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# ============================================================
# 23. Discount Percentage by Category
# ============================================================

plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="category",
    y="discount_percentage"
)

plt.title("Discount Percentage by Category")
plt.xlabel("Category")
plt.ylabel("Discount Percentage")

plt.xticks(rotation=30)

plt.tight_layout()
plt.show()

# ============================================================
# 24. Price by Category
# ============================================================

plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="category",
    y="discounted_price"
)

plt.title("Discounted Price by Category")
plt.xlabel("Category")
plt.ylabel("Discounted Price")

plt.xticks(rotation=30)

plt.tight_layout()
plt.show()

# ============================================================
# 25. Rating vs Rating Count
# ============================================================

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="rating",
    y="rating_count",
    s=100
)

plt.title("Rating vs Rating Count")
plt.xlabel("Rating")
plt.ylabel("Rating Count")

plt.tight_layout()
plt.show()

# ============================================================
# 26. Discount vs Rating
# ============================================================

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="discount_percentage",
    y="rating",
    s=100
)

plt.title("Discount Percentage vs Rating")
plt.xlabel("Discount Percentage")
plt.ylabel("Rating")

plt.tight_layout()
plt.show()

# ============================================================
# 27. Stock vs Discounted Price
# ============================================================

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="discounted_price",
    y="stock_available",
    s=100
)

plt.title("Discounted Price vs Stock Availability")
plt.xlabel("Discounted Price")
plt.ylabel("Stock Available")

plt.tight_layout()
plt.show()

# ============================================================
# 28. Pairplot
# ============================================================

sns.pairplot(
    df[
        [
            "actual_price_msrp",
            "discounted_price",
            "discount_percentage",
            "cost_price",
            "rating",
            "rating_count",
            "stock_available"
        ]
    ]
)

plt.show()

# ============================================================
# 29. Calculate Profit Margin
# ============================================================

df["profit"] = df["discounted_price"] - df["cost_price"]

df["profit_margin_percentage"] = (
    df["profit"] / df["discounted_price"]
) * 100

print("\n" + "=" * 60)
print("PROFIT ANALYSIS")
print("=" * 60)

print(df[
    [
        "product_name",
        "discounted_price",
        "cost_price",
        "profit",
        "profit_margin_percentage"
    ]
])

# ============================================================
# 30. Top Products by Profit
# ============================================================

top_profit = df.sort_values(
    "profit",
    ascending=False
).head(10)

plt.figure(figsize=(10, 6))

sns.barplot(
    data=top_profit,
    x="profit",
    y="product_name"
)

plt.title("Top Products by Profit")
plt.xlabel("Profit")
plt.ylabel("Product")

plt.tight_layout()
plt.show()

# ============================================================
# 31. Top Products by Discount
# ============================================================

top_discount = df.sort_values(
    "discount_percentage",
    ascending=False
).head(10)

plt.figure(figsize=(10, 6))

sns.barplot(
    data=top_discount,
    x="discount_percentage",
    y="product_name"
)

plt.title("Top Products by Discount Percentage")
plt.xlabel("Discount Percentage")
plt.ylabel("Product")

plt.tight_layout()
plt.show()

# ============================================================
# 32. Top Products by Rating
# ============================================================

top_rating = df.sort_values(
    "rating",
    ascending=False
).head(10)

plt.figure(figsize=(10, 6))

sns.barplot(
    data=top_rating,
    x="rating",
    y="product_name"
)

plt.title("Top Products by Rating")
plt.xlabel("Rating")
plt.ylabel("Product")

plt.tight_layout()
plt.show()

# ============================================================
# 33. EDA Summary
# ============================================================

print("\n" + "=" * 60)
print("EDA SUMMARY")
print("=" * 60)

print("Dataset Shape:", df.shape)
print("Total Products:", len(df))
print("Total Categories:", df["category"].nunique())
print("Total Sub-Categories:", df["sub_category"].nunique())

print(
    "Average Actual Price:",
    round(df["actual_price_msrp"].mean(), 2)
)

print(
    "Average Discounted Price:",
    round(df["discounted_price"].mean(), 2)
)

print(
    "Average Discount:",
    round(df["discount_percentage"].mean(), 2), "%"
)

print(
    "Average Rating:",
    round(df["rating"].mean(), 2)
)

print(
    "Average Stock:",
    round(df["stock_available"].mean(), 2)
)

print(
    "Average Profit:",
    round(df["profit"].mean(), 2)
)

print("\nEDA Completed Successfully!")
# Out:
# Dataset loaded successfully!
# Shape: (20, 11)
#       product_id                                   product_name     category  \
# 0  PROD_ELEC_001  Aura Pro Wireless Noise-Cancelling Headphones  Electronics
# 1  PROD_ELEC_002        UltraView 27-inch 4K UHD Gaming Monitor  Electronics
# 2  PROD_ELEC_003  Vortex Pulse Smartwatch with Heart Rate & GPS  Electronics
# 3  PROD_ELEC_004    HyperCharge 65W GaN Fast Charger Multi-Port  Electronics
# 4  PROD_ELEC_005         NovaCast 4K Streaming Media Player HDR  Electronics
#
#          sub_category  actual_price_msrp  discounted_price  \
# 0               Audio             199.99            157.99
# 1            Monitors             349.99            330.39
# 2           Wearables             149.99            132.14
# 3         Accessories              39.99             35.75
# 4  Home Entertainment              49.99             38.29
#
#    discount_percentage  cost_price  rating  rating_count  stock_available
# ...

# %%
# ============================================================
# 2. Load Dataset
# ============================================================

from google.colab import files

uploaded = files.upload()

filename = next(iter(uploaded))
df = pd.read_csv(filename)

print("Dataset loaded successfully!")
print("File:", filename)
print("Shape:", df.shape)
# Out:
#      <input type="file" id="files-b88321c5-bc10-4e2a-ad50-a083a027abe1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b88321c5-bc10-4e2a-ad50-a083a027abe1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ============================================================
# RETAIL PRICE OPTIMIZATION DATASET
# COMPLETE EXPLORATORY DATA ANALYSIS (EDA)
# ============================================================


# ============================================================
# 1. IMPORT LIBRARIES
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import glob

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

sns.set_theme(style="whitegrid")

print("Libraries imported successfully!")


# ============================================================
# 2. LOAD DATASET
# ============================================================

# Automatically find CSV files in the current notebook folder
csv_files = glob.glob("*.csv")

print("CSV files found:")
for file in csv_files:
    print(file)

if len(csv_files) == 0:
    raise FileNotFoundError(
        "No CSV file found. Please upload 'retail_price_optimization.csv' "
        "to the notebook folder."
    )

# If the required file exists, use it
required_file = "retail_price_optimization.csv"

if required_file in csv_files:
    file_path = required_file
else:
    # Use first CSV if exact filename is different
    file_path = csv_files[0]

df = pd.read_csv(file_path)

print("\nDataset loaded successfully!")
print("File:", file_path)
print("Shape:", df.shape)

display(df.head())


# ============================================================
# 3. BASIC DATASET INFORMATION
# ============================================================

print("\n========== FIRST 5 ROWS ==========")
display(df.head())

print("\n========== LAST 5 ROWS ==========")
display(df.tail())

print("\n========== DATASET SHAPE ==========")
print(df.shape)

print("\n========== COLUMN NAMES ==========")
print(df.columns.tolist())

print("\n========== DATASET INFO ==========")
df.info()

print("\n========== DATA TYPES ==========")
print(df.dtypes)


# ============================================================
# 4. MISSING VALUES ANALYSIS
# ============================================================

print("\n========== MISSING VALUES ==========")

missing_values = df.isnull().sum()

missing_percentage = (
    df.isnull().sum() / len(df) * 100
).round(2)

missing_df = pd.DataFrame({
    "Missing Values": missing_values,
    "Missing Percentage": missing_percentage
})

display(missing_df)

print("\nTotal missing values:", df.isnull().sum().sum())


# ============================================================
# 5. DUPLICATE VALUES
# ============================================================

print("\n========== DUPLICATE ROWS ==========")

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)

if duplicate_count > 0:
    df = df.drop_duplicates().reset_index(drop=True)
    print("Duplicates removed.")
else:
    print("No duplicate rows found.")


# ============================================================
# 6. STATISTICAL SUMMARY
# ============================================================

print("\n========== STATISTICAL SUMMARY ==========")

display(df.describe())

print("\n========== TRANSPOSED STATISTICAL SUMMARY ==========")

display(df.describe().T)


# ============================================================
# 7. UNIQUE VALUES
# ============================================================

print("\n========== UNIQUE VALUES ==========")

unique_values = df.nunique().sort_values()

display(unique_values.to_frame("Number of Unique Values"))


# ============================================================
# 8. NUMERICAL AND CATEGORICAL COLUMNS
# ============================================================

numeric_columns = df.select_dtypes(
    include=np.number
).columns.tolist()

categorical_columns = df.select_dtypes(
    exclude=np.number
).columns.tolist()

print("\n========== NUMERICAL COLUMNS ==========")
print(numeric_columns)

print("\n========== CATEGORICAL COLUMNS ==========")
print(categorical_columns)


# ============================================================
# 9. CORRELATION HEATMAP
# ============================================================

print("\n========== CORRELATION MATRIX ==========")

correlation_matrix = df[numeric_columns].corr()

display(correlation_matrix)

plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()


# ============================================================
# 10. HISTOGRAMS OF NUMERICAL VARIABLES
# ============================================================

print("\n========== NUMERICAL DISTRIBUTIONS ==========")

for column in numeric_columns:

    plt.figure(figsize=(8, 5))

    sns.histplot(
        data=df,
        x=column,
        kde=True
    )

    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()


# ============================================================
# 11. BOXPLOTS
# ============================================================

print("\n========== BOXPLOTS ==========")

for column in numeric_columns:

    plt.figure(figsize=(8, 4))

    sns.boxplot(
        x=df[column]
    )

    plt.title(f"Boxplot of {column}")
    plt.xlabel(column)

    plt.tight_layout()
    plt.show()


# ============================================================
# 12. PRODUCT CATEGORY DISTRIBUTION
# ============================================================

print("\n========== PRODUCT CATEGORY DISTRIBUTION ==========")

category_counts = df["product_category_name"].value_counts()

display(category_counts.to_frame("Count"))

plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    y="product_category_name",
    order=category_counts.index
)

plt.title("Product Category Distribution")
plt.xlabel("Number of Records")
plt
# Out:
# Libraries imported successfully!
# CSV files found:
# amazon_product_pricing.csv
# retail_price_optimization.csv
# brazilian_ecommerce_olist (1).csv
# retail_price_optimization (1).csv
# brazilian_ecommerce_olist.csv
#
# Dataset loaded successfully!
# File: retail_price_optimization.csv
# Shape: (1040, 13)
#       product_id product_category_name  week_num  unit_price  comp_1_price  \
# 0  PROD_ELEC_001           Electronics         1      204.96        207.93
# 1  PROD_ELEC_001           Electronics         2      197.65        197.01
# 2  PROD_ELEC_001           Electronics         3      189.86        196.04
# 3  PROD_ELEC_001           Electronics         4      197.73        202.65
# 4  PROD_ELEC_001           Electronics         5      199.86        195.40
#
#    comp_2_price  comp_3_price  freight_price  product_score  ps1  ps2  ps3  \
# 0        209.55        217.54          10.54            4.6  4.3  4.8  4.8
# ...

# %%
  from google.colab import files

uploaded = files.upload()

filename = next(iter(uploaded))
df = pd.read_csv(filename)

print("Dataset loaded successfully!")
print("File:", filename)
print("Shape:", df.shape)                                                                                                                                                                    # ============================================================
# RETAIL PRICE OPTIMIZATION DATASET
# COMPLETE EXPLORATORY DATA ANALYSIS (EDA)
# ============================================================


# ============================================================
# 1. IMPORT LIBRARIES
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import glob

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

sns.set_theme(style="whitegrid")

print("Libraries imported successfully!")


# ============================================================
# 2. LOAD DATASET
# ============================================================

# Automatically find CSV files in the current notebook folder
csv_files = glob.glob("*.csv")

print("CSV files found:")
for file in csv_files:
    print(file)

if len(csv_files) == 0:
    raise FileNotFoundError(
        "No CSV file found. Please upload 'retail_price_optimization.csv' "
        "to the notebook folder."
    )

# If the required file exists, use it
required_file = "retail_price_optimization.csv"

if required_file in csv_files:
    file_path = required_file
else:
    # Use first CSV if exact filename is different
    file_path = csv_files[0]

df = pd.read_csv(file_path)

print("\nDataset loaded successfully!")
print("File:", file_path)
print("Shape:", df.shape)

display(df.head())


# ============================================================
# 3. BASIC DATASET INFORMATION
# ============================================================

print("\n========== FIRST 5 ROWS ==========")
display(df.head())

print("\n========== LAST 5 ROWS ==========")
display(df.tail())

print("\n========== DATASET SHAPE ==========")
print(df.shape)

print("\n========== COLUMN NAMES ==========")
print(df.columns.tolist())

print("\n========== DATASET INFO ==========")
df.info()

print("\n========== DATA TYPES ==========")
print(df.dtypes)


# ============================================================
# 4. MISSING VALUES ANALYSIS
# ============================================================

print("\n========== MISSING VALUES ==========")

missing_values = df.isnull().sum()

missing_percentage = (
    df.isnull().sum() / len(df) * 100
).round(2)

missing_df = pd.DataFrame({
    "Missing Values": missing_values,
    "Missing Percentage": missing_percentage
})

display(missing_df)

print("\nTotal missing values:", df.isnull().sum().sum())


# ============================================================
# 5. DUPLICATE VALUES
# ============================================================

print("\n========== DUPLICATE ROWS ==========")

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)

if duplicate_count > 0:
    df = df.drop_duplicates().reset_index(drop=True)
    print("Duplicates removed.")
else:
    print("No duplicate rows found.")


# ============================================================
# 6. STATISTICAL SUMMARY
# ============================================================

print("\n========== STATISTICAL SUMMARY ==========")

display(df.describe())

print("\n========== TRANSPOSED STATISTICAL SUMMARY ==========")

display(df.describe().T)


# ============================================================
# 7. UNIQUE VALUES
# ============================================================

print("\n========== UNIQUE VALUES ==========")

unique_values = df.nunique().sort_values()

display(unique_values.to_frame("Number of Unique Values"))


# ============================================================
# 8. NUMERICAL AND CATEGORICAL COLUMNS
# ============================================================

numeric_columns = df.select_dtypes(
    include=np.number
).columns.tolist()

categorical_columns = df.select_dtypes(
    exclude=np.number
).columns.tolist()

print("\n========== NUMERICAL COLUMNS ==========")
print(numeric_columns)

print("\n========== CATEGORICAL COLUMNS ==========")
print(categorical_columns)


# ============================================================
# 9. CORRELATION HEATMAP
# ============================================================

print("\n========== CORRELATION MATRIX ==========")

correlation_matrix = df[numeric_columns].corr()

display(correlation_matrix)

plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()


# ============================================================
# 10. HISTOGRAMS OF NUMERICAL VARIABLES
# ============================================================

print("\n========== NUMERICAL DISTRIBUTIONS ==========")

for column in numeric_columns:

    plt.figure(figsize=(8, 5))

    sns.histplot(
        data=df,
        x=column,
        kde=True
    )

    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()


# ============================================================
# 11. BOXPLOTS
# ============================================================

print("\n========== BOXPLOTS ==========")

for column in numeric_columns:

    plt.figure(figsize=(8, 4))

    sns.boxplot(
        x=df[column]
    )

    plt.title(f"Boxplot of {column}")
    plt.xlabel(column)

    plt.tight_layout()
    plt.show()


# ============================================================
# 12. PRODUCT CATEGORY DISTRIBUTION
# ============================================================

print("\n========== PRODUCT CATEGORY DISTRIBUTION ==========")

category_counts = df["product_category_name"].value_counts()

display(category_counts.to_frame("Count"))

plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    y="product_category_name",
    order=category_counts.index
)

plt.title("Product Category Distribution")
plt.xlabel("Number of Records")
plt.ylabel("Product Category")

plt.tight_layout()
plt.show()


# ============================================================
# 13. WEEKLY SALES DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x="weekly_sales_volume",
    kde=True
)

plt.title("Weekly Sales Volume Distribution")
plt.xlabel("Weekly Sales Volume")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()


# ============================================================
# 14. UNIT PRICE DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x="unit_price",
    kde=True
)

plt.title("Unit Price Distribution")
plt.xlabel("Unit Price")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()


# ============================================================
# 15. FREIGHT PRICE DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x="freight_price",
    kde=True
)

plt.title("Freight Price Distribution")
plt.xlabel("Freight Price")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()


# ============================================================
# 16. PRODUCT SCORE DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x="product_score",
    kde=True
)

plt.title("Product Score Distribution")
plt.xlabel("Product Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()


# ============================================================
# 17. COMPETITOR PRICE COMPARISON ACROSS WEEKS
# ============================================================

weekly_prices = df.groupby("week_num")[
    [
        "unit_price",
        "comp_1_price",
        "comp_2_price",
        "comp_3_price"
    ]
].mean()

plt.figure(figsize=(12, 6))

plt.plot(
    weekly_prices.index,
    weekly_prices["unit_price"],
    label="Our Price"
)

plt.plot(
    weekly_prices.index,
    weekly_prices["comp_1_price"],
    label="Competitor 1"
)

plt.plot(
    weekly_prices.index,
    weekly_prices["comp_2_price"],
    label="Competitor 2"
)

plt.plot(
    weekly_prices.index,
    weekly_prices["comp_3_price"],
    label="Competitor 3"
)

plt.title("Average Price Comparison Across Weeks")
plt.xlabel("Week Number")
plt.ylabel("Price")
plt.legend()

plt.tight_layout()
plt.show()


# ============================================================
# 18. OUR PRICE VS COMPETITOR 1
# ============================================================

plt.figure(figsize=(8, 6))

sns.scatterplot(
    data=df,
    x="unit_price",
    y="comp_1_price"
)

plt.title("Our Price vs Competitor 1 Price")
plt.xlabel("Our Unit Price")
plt.ylabel("Competitor 1 Price")

plt.tight_layout()
plt.show()


# ============================================================
# 19. OUR PRICE VS COMPETITOR 2
# ============================================================

plt.figure(figsize=(8, 6))

sns.scatterplot(
    data=df,
    x="unit_price",
    y="comp_2_price"
)

plt.title("Our Price vs Competitor 2 Price")
plt.xlabel("Our Unit Price")
plt.ylabel("Competitor 2 Price")

plt.tight_layout()
plt.show()


# ============================================================
# 20. OUR PRICE VS COMPETITOR 3
# ============================================================

plt.figure(figsize=(8, 6))

sns.scatterplot(
    data=df,
    x="unit_price",
    y="comp_3_price"
)

plt.title("Our Price vs Competitor 3 Price")
plt.xlabel("Our Unit Price")
plt.ylabel("Competitor 3 Price")

plt.tight_layout()
plt.show()


# ============================================================
# 21. UNIT PRICE VS WEEKLY SALES
# ============================================================

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="unit_price",
    y="weekly_sales_volume",
    hue="product_category_name"
)

plt.title("Unit Price vs Weekly Sales Volume")
plt.xlabel("Unit Price")
plt.ylabel("Weekly Sales Volume")

plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)

plt.tight_layout()
plt.show()


# ============================================================
# 22. FREIGHT PRICE VS WEEKLY SALES
# ============================================================

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="freight_price",
    y="weekly_sales_volume"
)

plt.title("Freight Price vs Weekly Sales Volume")
plt.xlabel("Freight Price")
plt.ylabel("Weekly Sales Volume")

plt.tight_layout()
plt.show()


# ============================================================
# 23. PRODUCT SCORE VS WEEKLY SALES
# ============================================================

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="product_score",
    y="weekly_sales_volume"
)

plt.title("Product Score vs Weekly Sales Volume")
plt.xlabel("Product Score")
plt.ylabel("Weekly Sales Volume")

plt.tight_layout()
plt.show()


# ============================================================
# 24. COMPETITOR PRICE GAPS
# ============================================================

df["comp_1_gap"] = df["unit_price"] - df["comp_1_price"]
df["comp_2_gap"] = df["unit_price"] - df["comp_2_price"]
df["comp_3_gap"] = df["unit_price"] - df["comp_3_price"]

df["avg_competitor_price"] = df[
    [
        "comp_1_price",
        "comp_2_price",
        "comp_3_price"
    ]
].mean(axis=1)

df["avg_competitor_gap"] = (
    df["unit_price"] - df["avg_competitor_price"]
)

print("\n========== COMPETITOR PRICE GAPS ==========")

display(
    df[
        [
            "unit_price",
            "comp_1_price",
            "comp_2_price",
            "comp_3_price",
            "avg_competitor_price",
            "avg_competitor_gap"
        ]
    ].head()
)


# ============================================================
# 25. OUR PRICE VS AVERAGE COMPETITOR PRICE
# ============================================================

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="avg_competitor_price",
    y="unit_price"
)

# Reference line
min_price = min(
    df["avg_competitor_price"].min(),
    df["unit_price"].min()
)

max_price = max(
    df["avg_competitor_price"].max(),
    df["unit_price"].max()
)

plt.plot(
    [min_price, max_price],
    [min_price, max_price],
    linestyle="--",
    label="Equal Price"
)

plt.title("Our Price vs Average Competitor Price")
plt.xlabel("Average Competitor Price")
plt.ylabel("Our Unit Price")
plt.legend()

plt.tight_layout()
plt.show()


# ============================================================
# 26. COMPETITOR GAP DISTRIBUTION
# ============================================================

gap_columns = [
    "comp_1_gap",
    "comp_2_gap",
    "comp_3_gap"
]

for column in gap_columns:

    plt.figure(figsize=(8, 5))

    sns.histplot(
        data=df,
        x=column,
        kde=True
    )

    plt.axvline(
        0,
        linestyle="--"
    )

    plt.title(f"Distribution of {column}")
    plt.xlabel("Price Gap")
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()


# ============================================================
# 27. WEEKLY SALES BY CATEGORY
# ============================================================

category_sales = (
    df.groupby("product_category_name")[
        "weekly_sales_volume"
    ]
    .mean()
    .sort_values(ascending=False)
)

print("\n========== AVERAGE SALES BY CATEGORY ==========")

display(
    category_sales.to_frame("Average Weekly Sales")
)

plt.figure(figsize=(10, 6))

category_sales.plot(
    kind="bar"
)

plt.title("Average Weekly Sales by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Average Weekly Sales")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


# ============================================================
# 28. UNIT PRICE BY CATEGORY
# ============================================================

category_price = (
    df.groupby("product_category_name")[
        "unit_price"
    ]
    .mean()
    .sort_values(ascending=False)
)

print("\n========== AVERAGE UNIT PRICE BY CATEGORY ==========")

display(
    category_price.to_frame("Average Unit Price")
)

plt.figure(figsize=(10, 6))

category_price.plot(
    kind="bar"
)

plt.title("Average Unit Price by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Average Unit Price")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


# ============================================================
# 29. AVERAGE SALES BY WEEK
# ============================================================

weekly_sales = (
    df.groupby("week_num")[
        "weekly_sales_volume"
    ]
    .mean()
)

plt.figure(figsize=(12, 6))

plt.plot(
    weekly_sales.index,
    weekly_sales.values,
    marker="o"
)

plt.title("Average Weekly Sales Trend")
plt.xlabel("Week Number")
plt.ylabel("Average Weekly Sales")

plt.xticks(
    sorted(df["week_num"].unique())
)

plt.tight_layout()
plt.show()


# ============================================================
# 30. AVERAGE PRICE BY WEEK
# ============================================================

weekly_unit_price = (
    df.groupby("week_num")[
        "unit_price"
    ]
    .mean()
)

plt.figure(figsize=(12, 6))

plt.plot(
    weekly_unit_price.index,
    weekly_unit_price.values,
    marker="o"
)

plt.title("Average Unit Price Trend by Week")
plt.xlabel("Week Number")
plt.ylabel("Average Unit Price")

plt.xticks(
    sorted(df["week_num"].unique())
)

plt.tight_layout()
plt.show()


# ============================================================
# 31. PRICE ELASTICITY ANALYSIS
# ============================================================

print("\n========== PRICE ELASTICITY ANALYSIS ==========")

# Sort by product and week
elasticity_df = df.sort_values(
    ["product_id", "week_num"]
).copy()

# Percentage change in price
elasticity_df["price_pct_change"] = (
    elasticity_df
    .groupby("product_id")["unit_price"]
    .pct_change()
)

# Percentage change in sales
elasticity_df["sales_pct_change"] = (
    elasticity_df
    .groupby("product_id")["weekly_sales_volume"]
    .pct_change()
)

# Avoid division by zero
elasticity_df["price_elasticity"] = np.where(
    elasticity_df["price_pct_change"].abs() > 1e-10,
    elasticity_df["sales_pct_change"]
    / elasticity_df["price_pct_change"],
    np.nan
)

# Replace infinite values
elasticity_df["price_elasticity"] = (
    elasticity_df["price_elasticity"]
    .replace([np.inf, -np.inf], np.nan)
)

print("\nPrice Elasticity Summary:")

display(
    elasticity_df["price_elasticity"].describe()
)

# Mean elasticity by product
product_elasticity = (
    elasticity_df
    .groupby("product_id")["price_elasticity"]
    .mean()
    .sort_values()
)

print("\n========== ELASTICITY BY PRODUCT ==========")

display(
    product_elasticity.to_frame(
        "Average Price Elasticity"
    )
)


# ============================================================
# 32. WEEKLY REVENUE CALCULATION
# ============================================================

df["weekly_revenue"] = (
    df["unit_price"] *
    df["weekly_sales_volume"]
)

print("\n========== WEEKLY REVENUE ==========")

display(
    df[
        [
            "product_id",
            "week_num",
            "unit_price",
            "weekly_sales_volume",
            "weekly_revenue"
        ]
    ].head()
)

print(
    "\nTotal Revenue:",
    round(df["weekly_revenue"].sum(), 2)
)

print(
    "Average Weekly Revenue:",
    round(df["weekly_revenue"].mean(), 2)
)


# ============================================================
# 33. WEEKLY REVENUE TREND
# ============================================================

weekly_revenue = (
    df.groupby("week_num")[
        "weekly_revenue"
    ]
    .sum()
)

plt.figure(figsize=(12, 6))

plt.plot(
    weekly_revenue.index,
    weekly_revenue.values,
    marker="o"
)

plt.title("Weekly Revenue Trend")
plt.xlabel("Week Number")
plt.ylabel("Total Revenue")

plt.xticks(
    sorted(df["week_num"].unique())
)

plt.tight_layout()
plt.show()


# ============================================================
# 34. REVENUE BY CATEGORY
# ============================================================

category_revenue = (
    df.groupby("product_category_name")[
        "weekly_revenue"
    ]
    .sum()
    .sort_values(ascending=False)
)

print("\n========== REVENUE BY CATEGORY ==========")

display(
    category_revenue.to_frame(
        "Total Revenue"
    )
)

plt.figure(figsize=(10, 6))

category_revenue.plot(
    kind="bar"
)

plt.title("Total Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


# ============================================================
# 35. PAIRPLOT
# ============================================================

print("\n========== PAIRPLOT ==========")

pairplot_columns = [
    "unit_price",
    "avg_competitor_price",
    "freight_price",
    "product_score",
    "weekly_sales_volume"
]

sns.pairplot(
    df[pairplot_columns],
    diag_kind="hist"
)

plt.show()


# ============================================================
# 36. TOP PRODUCTS BY REVENUE
# ============================================================

top_products_revenue = (
    df.groupby("product_id")[
        "weekly_revenue"
    ]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print("\n========== TOP 10 PRODUCTS BY REVENUE ==========")

display(
    top_products_revenue.to_frame(
        "Total Revenue"
    )
)

plt.figure(figsize=(10, 6))

top_products_revenue.sort_values().plot(
    kind="barh"
)

plt.title("Top 10 Products by Total Revenue")
plt.xlabel("Total Revenue")
plt.ylabel("Product ID")

plt.tight_layout()
plt.show()


# ============================================================
# 37. TOP PRODUCTS BY SALES VOLUME
# ============================================================

top_products_sales = (
    df.groupby("product_id")[
        "weekly_sales_volume"
    ]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print("\n========== TOP 10 PRODUCTS BY SALES VOLUME ==========")

display(
    top_products_sales.to_frame(
        "Total Sales Volume"
    )
)

plt.figure(figsize=(10, 6))

top_products_sales.sort_values().plot(
    kind="barh"
)

plt.title("Top 10 Products by Sales Volume")
plt.xlabel("Total Sales Volume")
plt.ylabel("Product ID")

plt.tight_layout()
plt.show()


# ============================================================
# 38. FINAL EDA SUMMARY
# ============================================================

print("\n")
print("=" * 70)
print("              RETAIL PRICE OPTIMIZATION EDA SUMMARY")
print("=" * 70)

print("\nDataset Shape:")
print(df.shape)

print("\nNumber of Products:")
print(df["product_id"].nunique())

print("\nNumber of Categories:")
print(df["product_category_name"].nunique())

print("\nNumber of Weeks:")
print(df["week_num"].nunique())

print("\nTotal Missing Values:")
print(df.isnull().sum().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())

print("\nAverage Unit Price:")
print(round(df["unit_price"].mean(), 2))

print("\nAverage Competitor Price:")
print(round(df["avg_competitor_price"].mean(), 2))

print("\nAverage Weekly Sales:")
print(round(df["weekly_sales_volume"].mean(), 2))

print("\nAverage Product Score:")
print(round(df["product_score"].mean(), 2))

print("\nTotal Revenue:")
print(round(df["weekly_revenue"].sum(), 2))

print("\nHighest Revenue Product:")
print(
    top_products_revenue.index[0]
)

print("\nHighest Sales Product:")
print(
    top_products_sales.index[0]
)

print("\nBest Revenue Category:")
print(
    category_revenue.index[0]
)

print("\nBest Sales Category:")
print(
    category_sales.index[0]
)

print("\n" + "=" * 70)
print("EDA COMPLETED SUCCESSFULLY!")
print("=" * 70)
# Out:
#      <input type="file" id="files-d978cf5c-62db-4c30-a2f5-fbab0e09859e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d978cf5c-62db-4c30-a2f5-fbab0e09859e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cdffbd7f-0a1e-4acb-82f0-7f16645d4a0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdffbd7f-0a1e-4acb-82f0-7f16645d4a0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ============================================================
# FAVORITA STORE SALES DATASET
# COMPLETE EXPLORATORY DATA ANALYSIS (EDA)
# ============================================================


# ============================================================
# 1. IMPORT LIBRARIES
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

sns.set_theme(style="whitegrid")

print("Libraries imported successfully!")


# ============================================================
# 2. UPLOAD DATASET
# ============================================================

# Google Colab upload
from google.colab import files

uploaded = files.upload()

filename = next(iter(uploaded))

df = pd.read_csv(filename)

print("\nDataset loaded successfully!")
print("File:", filename)
print("Shape:", df.shape)

display(df.head())


# ============================================================
# 3. BASIC DATASET INFORMATION
# ============================================================

print("\n========== FIRST 5 ROWS ==========")
display(df.head())

print("\n========== LAST 5 ROWS ==========")
display(df.tail())

print("\n========== DATASET SHAPE ==========")
print(df.shape)

print("\n========== COLUMN NAMES ==========")
print(df.columns.tolist())

print("\n========== DATASET INFO ==========")
df.info()

print("\n========== DATA TYPES ==========")
print(df.dtypes)


# ============================================================
# 4. DATE CONVERSION
# ============================================================

print("\n========== DATE CONVERSION ==========")

df["date"] = pd.to_datetime(
    df["date"],
    errors="coerce"
)

print("Date column converted successfully.")

print("Minimum Date:", df["date"].min())
print("Maximum Date:", df["date"].max())


# ============================================================
# 5. MISSING VALUES ANALYSIS
# ============================================================

print("\n========== MISSING VALUES ==========")

missing_values = df.isnull().sum()

missing_percentage = (
    df.isnull().sum() / len(df) * 100
).round(2)

missing_df = pd.DataFrame({
    "Missing Values": missing_values,
    "Missing Percentage": missing_percentage
})

display(missing_df)

print(
    "\nTotal Missing Values:",
    df.isnull().sum().sum()
)


# ============================================================
# 6. DUPLICATE VALUES
# ============================================================

print("\n========== DUPLICATE ROWS ==========")

duplicate_count = df.duplicated().sum()

print(
    "Number of duplicate rows:",
    duplicate_count
)

if duplicate_count > 0:

    df = df.drop_duplicates().reset_index(drop=True)

    print("Duplicates removed.")

else:

    print("No duplicate rows found.")


# ============================================================
# 7. STATISTICAL SUMMARY
# ============================================================

print("\n========== STATISTICAL SUMMARY ==========")

display(df.describe())

print("\n========== TRANSPOSED STATISTICAL SUMMARY ==========")

display(df.describe().T)


# ============================================================
# 8. UNIQUE VALUES
# ============================================================

print("\n========== UNIQUE VALUES ==========")

unique_values = df.nunique().sort_values()

display(
    unique_values.to_frame(
        "Number of Unique Values"
    )
)


# ============================================================
# 9. NUMERICAL AND CATEGORICAL COLUMNS
# ============================================================

numeric_columns = df.select_dtypes(
    include=np.number
).columns.tolist()

categorical_columns = df.select_dtypes(
    exclude=np.number
).columns.tolist()

print("\n========== NUMERICAL COLUMNS ==========")
print(numeric_columns)

print("\n========== CATEGORICAL COLUMNS ==========")
print(categorical_columns)


# ============================================================
# 10. CORRELATION MATRIX
# ============================================================

print("\n========== CORRELATION MATRIX ==========")

correlation_matrix = df[numeric_columns].corr()

display(correlation_matrix)


# ============================================================
# 11. CORRELATION HEATMAP
# ============================================================

plt.figure(figsize=(10, 7))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title(
    "Correlation Heatmap - Favorita Store Sales"
)

plt.tight_layout()
plt.show()


# ============================================================
# 12. NUMERICAL DISTRIBUTIONS
# ============================================================

print("\n========== NUMERICAL DISTRIBUTIONS ==========")

for column in numeric_columns:

    plt.figure(figsize=(8, 5))

    sns.histplot(
        data=df,
        x=column,
        kde=True
    )

    plt.title(
        f"Distribution of {column}"
    )

    plt.xlabel(column)
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()


# ============================================================
# 13. BOXPLOTS
# ============================================================

print("\n========== BOXPLOTS ==========")

for column in numeric_columns:

    plt.figure(figsize=(8, 4))

    sns.boxplot(
        x=df[column]
    )

    plt.title(
        f"Boxplot of {column}"
    )

    plt.xlabel(column)

    plt.tight_layout()
    plt.show()


# ============================================================
# 14. PRODUCT FAMILY DISTRIBUTION
# ============================================================

print("\n========== PRODUCT FAMILY DISTRIBUTION ==========")

family_counts = (
    df["family"]
    .value_counts()
)

display(
    family_counts.to_frame("Count")
)

plt.figure(figsize=(10, 8))

sns.barplot(
    x=family_counts.values,
    y=family_counts.index
)

plt.title(
    "Product Family Distribution"
)

plt.xlabel("Number of Records")
plt.ylabel("Product Family")

plt.tight_layout()
plt.show()


# ============================================================
# 15. STORE DISTRIBUTION
# ============================================================

print("\n========== STORE DISTRIBUTION ==========")

store_counts = (
    df["store_nbr"]
    .value_counts()
    .sort_index()
)

display(
    store_counts.to_frame("Number of Records")
)

plt.figure(figsize=(12, 6))

sns.barplot(
    x=store_counts.index,
    y=store_counts.values
)

plt.title(
    "Number of Records by Store"
)

plt.xlabel("Store Number")
plt.ylabel("Number of Records")

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()


# ============================================================
# 16. PRODUCT DISTRIBUTION
# ============================================================

print("\n========== PRODUCT DISTRIBUTION ==========")

product_counts = (
    df["product_id"]
    .value_counts()
    .head(20)
)

display(
    product_counts.to_frame("Count")
)

plt.figure(figsize=(12, 7))

sns.barplot(
    x=product_counts.values,
    y=product_counts.index
)

plt.title(
    "Top 20 Products by Number of Records"
)

plt.xlabel("Number of Records")
plt.ylabel("Product ID")

plt.tight_layout()
plt.show()


# ============================================================
# 17. SALES UNITS DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x="sales_units",
    kde=True
)

plt.title(
    "Sales Units Distribution"
)

plt.xlabel("Sales Units")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()


# ============================================================
# 18. PROMOTION DISTRIBUTION
# ============================================================

print("\n========== PROMOTION DISTRIBUTION ==========")

promotion_counts = (
    df["onpromotion"]
    .value_counts()
)

display(
    promotion_counts.to_frame(
        "Number of Records"
    )
)

plt.figure(figsize=(7, 5))

sns.countplot(
    data=df,
    x="onpromotion"
)

plt.title(
    "Promotion Status Distribution"
)

plt.xlabel(
    "On Promotion (0 = No, 1 = Yes)"
)

plt.ylabel("Number of Records")

plt.tight_layout()
plt.show()


# ============================================================
# 19. HOLIDAY DISTRIBUTION
# ============================================================

print("\n========== HOLIDAY DISTRIBUTION ==========")

holiday_counts = (
    df["is_holiday"]
    .value_counts()
)

display(
    holiday_counts.to_frame(
        "Number of Records"
    )
)

plt.figure(figsize=(7, 5))

sns.countplot(
    data=df,
    x="is_holiday"
)

plt.title(
    "Holiday vs Non-Holiday Distribution"
)

plt.xlabel(
    "Holiday (0 = No, 1 = Yes)"
)

plt.ylabel("Number of Records")

plt.tight_layout()
plt.show()


# ============================================================
# 20. PROMOTION VS SALES
# ============================================================

print("\n========== PROMOTION VS SALES ==========")

promotion_sales = (
    df.groupby("onpromotion")[
        "sales_units"
    ]
    .mean()
)

display(
    promotion_sales.to_frame(
        "Average Sales Units"
    )
)

plt.figure(figsize=(7, 5))

sns.barplot(
    x=promotion_sales.index,
    y=promotion_sales.values
)

plt.title(
    "Average Sales: Promotion vs Non-Promotion"
)

plt.xlabel(
    "Promotion (0 = No, 1 = Yes)"
)

plt.ylabel("Average Sales Units")

plt.tight_layout()
plt.show()


# ============================================================
# 21. HOLIDAY VS SALES
# ============================================================

print("\n========== HOLIDAY VS SALES ==========")

holiday_sales = (
    df.groupby("is_holiday")[
        "sales_units"
    ]
    .mean()
)

display(
    holiday_sales.to_frame(
        "Average Sales Units"
    )
)

plt.figure(figsize=(7, 5))

sns.barplot(
    x=holiday_sales.index,
    y=holiday_sales.values
)

plt.title(
    "Average Sales: Holiday vs Non-Holiday"
)

plt.xlabel(
    "Holiday (0 = No, 1 = Yes)"
)

plt.ylabel("Average Sales Units")

plt.tight_layout()
plt.show()


# ============================================================
# 22. ECONOMIC OIL INDEX DISTRIBUTION
# ============================================================

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x="economic_oil_index",
    kde=True
)

plt.title(
    "Economic Oil Index Distribution"
)

plt.xlabel("Economic Oil Index")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()


# ============================================================
# 23. OIL INDEX VS SALES
# ============================================================

plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="economic_oil_index",
    y="sales_units"
)

plt.title(
    "Economic Oil Index vs Sales Units"
)

plt.xlabel("Economic Oil Index")
plt.ylabel("Sales Units")

plt.tight_layout()
plt.show()


# ============================================================
# 24. STORE VS SALES
# ============================================================

store_sales = (
    df.groupby("store_nbr")[
        "sales_units"
    ]
    .mean()
    .sort_values(ascending=False)
)

print("\n========== AVERAGE SALES BY STORE ==========")

display(
    store_sales.to_frame(
        "Average Sales Units"
    )
)

plt.figure(figsize=(12, 6))

sns.barplot(
    x=store_sales.index,
    y=store_sales.values
)

plt.title(
    "Average Sales Units by Store"
)

plt.xlabel("Store Number")
plt.ylabel("Average Sales Units")

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()


# ============================================================
# 25. PRODUCT FAMILY VS SALES
# ============================================================

family_sales = (
    df.groupby("family")[
        "sales_units"
    ]
    .mean()
    .sort_values(ascending=False)
)

print("\n========== AVERAGE SALES BY PRODUCT FAMILY ==========")

display(
    family_sales.to_frame(
        "Average Sales Units"
    )
)

plt.figure(figsize=(10, 8))

sns.barplot(
    x=family_sales.values,
    y=family_sales.index
)

plt.title(
    "Average Sales Units by Product Family"
)

plt.xlabel("Average Sales Units")
plt.ylabel("Product Family")

plt.tight_layout()
plt.show()


# ============================================================
# 26. TOP PRODUCTS BY SALES
# ============================================================

top_products_sales = (
    df.groupby("product_id")[
        "sales_units"
    ]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print("\n========== TOP 10 PRODUCTS BY SALES ==========")

display(
    top_products_sales.to_frame(
        "Total Sales Units"
    )
)

plt.figure(figsize=(10, 6))

top_products_sales.sort_values().plot(
    kind="barh"
)

plt.title(
    "Top 10 Products by Total Sales Units"
)

plt.xlabel("Total Sales Units")
plt.ylabel("Product ID")

plt.tight_layout()
plt.show()


# ============================================================
# 27. TOP PRODUCT FAMILIES BY SALES
# ============================================================

top_families_sales = (
    df.groupby("family")[
        "sales_units"
    ]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print("\n========== TOP PRODUCT FAMILIES BY SALES ==========")

display(
    top_families_sales.to_frame(
        "Total Sales Units"
    )
)

plt.figure(figsize=(10, 6))

top_families_sales.sort_values().plot(
    kind="barh"
)

plt.title(
    "Top Product Families by Total Sales"
)

plt.xlabel("Total Sales Units")
plt.ylabel("Product Family")

plt.tight_layout()
plt.show()


# ============================================================
# 28. SALES BY DATE
# ============================================================

daily_sales = (
    df.groupby("date")[
        "sales_units"
    ]
    .sum()
)

print("\n========== DAILY SALES ==========")

display(
    daily_sales.head(20).to_frame(
        "Total Sales Units"
    )
)

plt.figure(figsize=(14, 6))

plt.plot(
    daily_sales.index,
    daily_sales.values
)

plt.title(
    "Daily Sales Trend"
)

plt.xlabel("Date")
plt.ylabel("Total Sales Units")

plt.tight_layout()
plt.show()


# ============================================================
# 29. MONTHLY SALES TREND
# ============================================================

df["month"] = df["date"].dt.month

monthly_sales = (
    df.groupby("month")[
        "sales_units"
    ]
    .sum()
)

print("\n========== MONTHLY SALES ==========")

display(
    monthly_sales.to_frame(
        "Total Sales Units"
    )
)

plt.figure(figsize=(10, 6))

plt.plot(
    monthly_sales.index,
    monthly_sales.values,
    marker="o"
)

plt.title(
    "Monthly Sales Trend"
)

plt.xlabel("Month")
plt.ylabel("Total Sales Units")

plt.xticks(
    sorted(monthly_sales.index)
)

plt.tight_layout()
plt.show()


# ============================================================
# 30. DAY OF WEEK ANALYSIS
# ============================================================

df["day_of_week"] = (
    df["date"]
    .dt.day_name()
)

day_order = [
    "Monday",
    "Tuesday",
    "Wednesday",
    "Thursday",
    "Friday",
    "Saturday",
    "Sunday"
]

day_sales = (
    df.groupby("day_of_week")[
        "sales_units"
    ]
    .mean()
    .reindex(day_order)
)

print("\n========== SALES BY DAY OF WEEK ==========")

display(
    day_sales.to_frame(
        "Average Sales Units"
    )
)

plt.figure(figsize=(10, 6))

sns.barplot(
    x=day_sales.index,
    y=day_sales.values
)

plt.title(
    "Average Sales by Day of Week"
)

plt.xlabel("Day of Week")
plt.ylabel("Average Sales Units")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


# ============================================================
# 31. WEEKEND VS WEEKDAY
# ============================================================

df["is_weekend"] = (
    df["date"]
    .dt.dayofweek >= 5
).astype(int)

weekend_sales = (
    df.groupby("is_weekend")[
        "sales_units"
    ]
    .mean()
)

print("\n========== WEEKEND VS WEEKDAY SALES ==========")

display(
    weekend_sales.to_frame(
        "Average Sales Units"
    )
)

plt.figure(figsize=(7, 5))

sns.barplot(
    x=weekend_sales.index,
    y=weekend_sales.values
)

plt.title(
    "Average Sales: Weekend vs Weekday"
)

plt.xlabel(
    "Weekend (0 = Weekday, 1 = Weekend)"
)

plt.ylabel("Average Sales Units")

plt.tight_layout()
plt.show()


# ============================================================
# 32. SALES BY STORE AND PRODUCT FAMILY
# ============================================================

store_family_sales = pd.pivot_table(
    df,
    values="sales_units",
    index="store_nbr",
    columns="family",
    aggfunc="mean"
)

print(
    "\n========== STORE × PRODUCT FAMILY SALES =========="
)

display(
    store_family_sales.head(10)
)


# ============================================================
# 33. STORE × FAMILY HEATMAP
# ============================================================

# Show top 15 stores for readability

top_stores = (
    df.groupby("store_nbr")[
        "sales_units"
    ]
    .sum()
    .nlargest(15)
    .index
)

heatmap_data = (
    store_family_sales
    .loc[top_stores]
)

plt.figure(figsize=(16, 10))

sns.heatmap(
    heatmap_data,
    cmap="YlGnBu"
)

plt.title(
    "Average Sales by Store and Product Family"
)

plt.xlabel("Product Family")
plt.ylabel("Store Number")

plt.tight_layout()
plt.show()


# ============================================================
# 34. PROMOTION × PRODUCT FAMILY
# ============================================================

promotion_family = pd.pivot_table(
    df,
    values="sales_units",
    index="family",
    columns="onpromotion",
    aggfunc="mean"
)

print(
    "\n========== PROMOTION × PRODUCT FAMILY =========="
)

display(
    promotion_family
)

plt.figure(figsize=(12, 8))

sns.heatmap(
    promotion_family,
    annot=True,
    fmt=".1f",
    cmap="coolwarm"
)

plt.title(
    "Average Sales by Product Family and Promotion"
)

plt.xlabel(
    "Promotion (0 = No, 1 = Yes)"
)

plt.ylabel("Product Family")

plt.tight_layout()
plt.show()


# ============================================================
# 35. HOLIDAY × PRODUCT FAMILY
# ============================================================

holiday_family = pd.pivot_table(
    df,
    values="sales_units",
    index="family",
    columns="is_holiday",
    aggfunc="mean"
)

print(
    "\n========== HOLIDAY × PRODUCT FAMILY =========="
)

display(
    holiday_family
)

plt.figure(figsize=(12, 8))

sns.heatmap(
    holiday_family,
    annot=True,
    fmt=".1f",
    cmap="YlOrRd"
)

plt.title(
    "Average Sales by Product Family and Holiday"
)

plt.xlabel(
    "Holiday (0 = No, 1 = Yes)"
)

plt.ylabel("Product Family")

plt.tight_layout()
plt.show()


# ============================================================
# 36. SALES ELASTICITY / PROMOTION IMPACT
# ============================================================

print(
    "\n========== PROMOTION IMPACT BY PRODUCT FAMILY =========="
)

promotion_impact = (
    df.groupby(
        ["family", "onpromotion"]
    )["sales_units"]
    .mean()
    .unstack()
)

promotion_impact["promotion_lift"] = (
    (
        promotion_impact.get(1, np.nan)
        -
        promotion_impact.get(0, np.nan)
    )
    /
    promotion_impact.get(0, np.nan)
    * 100
)

display(
    promotion_impact.sort_values(
        "promotion_lift",
        ascending=False
    )
)


# ============================================================
# 37. TOP STORES BY TOTAL SALES
# ============================================================

top_stores_sales = (
    df.groupby("store_nbr")[
        "sales_units"
    ]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(
    "\n========== TOP 10 STORES BY SALES =========="
)

display(
    top_stores_sales.to_frame(
        "Total Sales Units"
    )
)

plt.figure(figsize=(10, 6))

top_stores_sales.sort_values().plot(
    kind="barh"
)

plt.title(
    "Top 10 Stores by Total Sales"
)

plt.xlabel("Total Sales Units")
plt.ylabel("Store Number")

plt.tight_layout()
plt.show()


# ============================================================
# 38. FINAL EDA SUMMARY
# ============================================================

print("\n")
print("=" * 75)
print("             FAVORITA STORE SALES EDA SUMMARY")
print("=" * 75)

print("\nDataset Shape:")
print(df.shape)

print("\nNumber of Stores:")
print(
    df["store_nbr"].nunique()
)

print("\nNumber of Products:")
print(
    df["product_id"].nunique()
)

print("\nNumber of Product Families:")
print(
    df["family"].nunique()
)

print("\nDate Range:")
print(
    df["date"].min(),
    "to",
    df["date"].max()
)

print("\nTotal Missing Values:")
print(
    df.isnull().sum().sum()
)

print("\nDuplicate Rows:")
print(
    df.duplicated().sum()
)

print("\nTotal Sales Units:")
print(
    df["sales_units"].sum()
)

print("\nAverage Sales Units:")
print(
    round(
        df["sales_units"].mean(),
        2
    )
)

print("\nMaximum Sales Units:")
print(
    df["sales_units"].max()
)

print("\nAverage Economic Oil Index:")
print(
    round(
        df["economic_oil_index"].mean(),
        2
    )
)

print("\nTop Selling Product:")
print(
    top_products_sales.index[0]
)

print("\nTop Selling Store:")
print(
    top_stores_sales.index[0]
)

print("\nTop Selling Product Family:")
print(
    top_families_sales.index[0]
)

print("\nBest Promotion Impact Family:")

if not promotion_impact["promotion_lift"].dropna().empty:
    print(
        promotion_impact[
            "promotion_lift"
        ].idxmax()
    )
else:
    print("Not available")


print("\n" + "=" * 75)
print("             EDA COMPLETED SUCCESSFULLY!")
print("=" * 75)
# Out:
# Libraries imported successfully!
#      <input type="file" id="files-ade0212e-d5f2-4114-ba0a-f2da51745bb1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ade0212e-d5f2-4114-ba0a-f2da51745bb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
